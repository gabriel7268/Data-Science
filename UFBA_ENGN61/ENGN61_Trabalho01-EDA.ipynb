# %%
# Convert to HTML
# %%shell
# jupyter nbconvert --to html //content/File Name Here.ipynb

# %% [markdown]
# # **Data Science** 💻
# # EDA and Visualization
# Gabriel Azevedo Anunciação

# %%
# %%html
# <marquee style='width: 85%; color: White;'><b>EDA and Visualization</b></marquee>
# Out:
# <marquee style='width: 85%; color: White; font: 10'><b>EDA and Visualization</b></marquee>

# %% [markdown]
# # Estatística Descritiva

# %%
# Importação das Bibliotecas:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ## Base de Dados: Europe  CO2 Emission
# [Fonte](https://www.kaggle.com/datasets/gabriel7268/co2-emission-europe-and-other-countries)
# [Download .csv](https://storage.googleapis.com/kagglesdsdata/datasets/3175936/5505596/europe_CO2emission.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230516%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230516T142625Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %%
# Leitura da Base de Dados, amazenamento na variável "europe":
europe = pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/3175936/5505596/europe_CO2emission.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230516%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230516T142625Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
# Exibição do DataFrame:
display(europe)
# Exibição do nº de linhas e colunas do DataFrame:
display(europe.shape)
# Out:
#     Country/Region                                               unit   2018  \
# 0          Germany                                   tCO2e per capita   8.18
# 1            Italy                                   tCO2e per capita   5.16
# 2           Poland                                   tCO2e per capita   7.35
# 3           France                                   tCO2e per capita   3.65
# 4            Spain                                   tCO2e per capita   5.20
# 5      Netherlands                                   tCO2e per capita   8.86
# 6          Belgium                                   tCO2e per capita   8.21
# 7   Czech Republic                                   tCO2e per capita   8.94
# 8           Greece                                   tCO2e per capita   6.19
# 9          Austria                                   tCO2e per capita   6.33
# 10         Romania                                   tCO2e per capita   2.69
# ...

# %%
# Seleção das 27 primeiras linhas, para excluir as 2 últimas:
europe = pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/3175936/5505596/countries_CO2emission.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230516%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230516T142736Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...", nrows=27)
# Remoção das colunas "unit" e "2018", alterando o DataFrame original:
europe.drop(['unit','2018'], axis=1, inplace=True)
# Alteração do nome das colunas:
europe.columns = ["Country", "CO2 Emission"]
display(europe)
display(europe.shape)
# Out:
#                              Country  CO2 Emission
# 0                        Afghanistan          0.16
# 1                            Albania          1.61
# 2                            Algeria          3.98
# 3                             Angola          1.91
# 4                          Argentina          4.40
# 5                          Australia         15.32
# 6                         Azerbaijan          3.35
# 7                            Bahamas          7.28
# 8                         Bangladesh          0.69
# 9                            Bolivia          7.79
# 10                            Brazil          3.88
# 11                          Cambodia          2.74
# 12                          Cameroon          1.67
# 13                            Canada         16.37
# 14                             Chile          1.77
# 15                             China          7.14
# 16                          Colombia          3.26
# ...

# %%
# Tipo da variável nome dos países:
print(type(europe.Country[0]))
# Tipo da variável Emissão de CO2:
print(type(europe['CO2 Emission'][0]))
# Número de itens nulos de cada variável:
print(europe.isnull().sum())
# Out:
# <class 'str'>
# <class 'numpy.float64'>
# Country         0
# CO2 Emission    0
# dtype: int64

# %%
# Cálculo da média
sum = 0
for i in range(len(europe['CO2 Emission'])):
  sum = sum + europe['CO2 Emission'][i]

mean = sum/len(europe['CO2 Emission'])
meanf = europe['CO2 Emission'].mean()
print("Média Calculada: {:.3}".format(mean))
print("Média Função: {:.3}".format(meanf))

europe_org = europe["CO2 Emission"].copy()

# Padronização coluna Emissão de CO2:
dp = europe['CO2 Emission'].std()
print("Desvio Padrão:", round(dp,4))

for i in range(len(europe['CO2 Emission'])):
  europe.loc[i,'CO2 Emission'] = (europe['CO2 Emission'][i] - mean)/dp

mean2 = europe['CO2 Emission'].mean()
print("----------")
print("Nova Média: ", (round(mean2)))
# Out:
# Média Calculada: 3.86
# Média Função: 3.86
# Desvio Padrão: 4.1158
# ----------
# Nova Média:  0

# %% [markdown]
# ## Base de Dados: Other Countries CO2 Emission
# [Fonte](https://www.kaggle.com/datasets/gabriel7268/co2-emission-europe-and-other-countries)
# [Download .csv](https://storage.googleapis.com/kagglesdsdata/datasets/3175936/5505596/countries_CO2emission.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230516%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230516T142736Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %%
other = pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/3175936/5505596/countries_CO2emission.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230516%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230516T142736Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...", usecols=['Country/Region','2019'])
other.columns = ["Country", "CO2 Emission"]
display(other)
# Out:
#         Country CO2 Emission
# 0   Afghanistan         0.16
# 1       Albania         1.61
# 2       Algeria         3.98
# 3        Angola         1.91
# 4     Argentina         4.40
# ..          ...          ...
# 68    Venezuela         5.45
# 69      Vietnam         3.36
# 70     Zimbabwe         6.75
# 71  Data source          NaN
# 72     Data for      Algeria
#
# [73 rows x 2 columns]

# %%
other = other.drop([71,72], axis=0)
display(other)
# Out:
#           Country CO2 Emission
# 0     Afghanistan         0.16
# 1         Albania         1.61
# 2         Algeria         3.98
# 3          Angola         1.91
# 4       Argentina         4.40
# ..            ...          ...
# 66  United States        13.97
# 67        Uruguay         1.36
# 68      Venezuela         5.45
# 69        Vietnam         3.36
# 70       Zimbabwe         6.75
#
# [71 rows x 2 columns]

# %%
print(other.dtypes)
print(other.isnull().sum())
# Out:
# Country         object
# CO2 Emission    object
# dtype: object
# Country         0
# CO2 Emission    0
# dtype: int64

# %%
other["CO2 Emission"] = pd.to_numeric(other["CO2 Emission"])
print(other.dtypes)
# Out:
# Country          object
# CO2 Emission    float64
# dtype: object

# %%
media = other["CO2 Emission"].mean()
print("Média:", round(media,2))

dp2 = other["CO2 Emission"].std()
print("Desvio Padrão:", round(dp,4))

other_org = other['CO2 Emission'].copy()

for i in range(len(other['CO2 Emission'])):
  other.loc[i,'CO2 Emission'] = (other['CO2 Emission'][i] - media)/dp2

media2 = other["CO2 Emission"].mean()
print("----------\n", end='')
print("Nova Média:", round(media2))
# Out:
# Média: 5.43
# Desvio Padrão: 4.1158
# ----------
# Nova Média: 0

# %%
# Concatenação (União) dos dois DataFrames de forma vertical, unindo países europeus com os demais
todos = pd.concat([europe,other], axis=0, ignore_index=True)
display(todos)
# Out:
#           Country  CO2 Emission
# 0     Afghanistan     -0.898608
# 1         Albania     -0.546310
# 2         Algeria      0.029516
# 3          Angola     -0.473420
# 4       Argentina      0.131561
# ..            ...           ...
# 93  United States      1.527874
# 94        Uruguay     -0.726891
# 95      Venezuela      0.004432
# 96        Vietnam     -0.369276
# 97       Zimbabwe      0.236882
#
# [98 rows x 2 columns]

# %%
# Ordenação por ordem alfabética do nome dos países
todos = todos.sort_values(by=['Country'])
# Resetar os índices
todos = todos.reset_index(drop=True)
display(todos)
# Out:
#           Country  CO2 Emission
# 0     Afghanistan     -0.898608
# 1     Afghanistan     -0.941460
# 2         Albania     -0.546310
# 3         Albania     -0.682189
# 4         Algeria      0.029516
# ..            ...           ...
# 93  United States      1.527874
# 94        Uruguay     -0.726891
# 95      Venezuela      0.004432
# 96        Vietnam     -0.369276
# 97       Zimbabwe      0.236882
#
# [98 rows x 2 columns]

# %% [markdown]
# ## Base de Dados: Countries of the World
# [Fonte](https://www.kaggle.com/datasets/fernandol/countries-of-the-world?resource=download)
# [Download .csv](https://storage.googleapis.com/kagglesdsdata/datasets/23752/30346/countries%20of%20the%20world.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230516%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230516T142855Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...)

# %%
countries = pd.read_csv("https://storage.googleapis.com/kagglesdsdata/datasets/23752/30346/countries%20of%20the%20world.csv?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230516%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230516T142855Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
display(countries)
print(countries.columns)
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
countries.drop(['Net migration','Arable (%)','Crops (%)','Other (%)','Service'], axis=1, inplace=True)
countries.sort_values(by=['Country'])
display(countries)
# Out:
#              Country                               Region  Population  \
# 0       Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1           Albania   EASTERN EUROPE                          3581655
# 2           Algeria   NORTHERN AFRICA                        32930091
# 3    American Samoa   OCEANIA                                   57794
# 4           Andorra   WESTERN EUROPE                            71201
# ..               ...                                  ...         ...
# 222       West Bank   NEAR EAST                               2460492
# 223  Western Sahara   NORTHERN AFRICA                          273008
# 224           Yemen   NEAR EAST                              21456188
# 225          Zambia   SUB-SAHARAN AFRICA                     11502010
# 226        Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# ...

# %%
print(todos.Country[0])
print(len(todos.Country[0]), "letras")
print(countries.Country[0])
print(len(countries.Country[0]), "letras")
print('\n')
print(todos.Country[1])
print(len(todos.Country[1]), "letras")
print(countries.Country[1])
print(len(countries.Country[1]), "letras")
print('\n')
print(todos.Country[2])
print(len(todos.Country[2]), "letras")
print(countries.Country[2])
print(len(countries.Country[2]), "letras")
# Out:
# Afghanistan
# 11 letras
# Afghanistan
# 12 letras
#
#
# Afghanistan
# 11 letras
# Albania
# 8 letras
#
#
# Albania
# 7 letras
# Algeria
# 8 letras

# %%
# Removendo o espaço no final do nome do país
for i in range(len(countries.Country)):
  countries.loc[i,'Country'] = countries.Country[i].strip()

print(todos.Country[0])
print(len(todos.Country[0]), "letras")
print(countries.Country[0])
print(len(countries.Country[0]), "letras")
print('\n')
print(todos.Country[1])
print(len(todos.Country[1]), "letras")
print(countries.Country[1])
print(len(countries.Country[1]), "letras")
print('\n')
print(todos.Country[2])
print(len(todos.Country[2]), "letras")
print(countries.Country[2])
print(len(countries.Country[2]), "letras")
# Out:
# Afghanistan
# 11 letras
# Afghanistan
# 11 letras
#
#
# Afghanistan
# 11 letras
# Albania
# 7 letras
#
#
# Albania
# 7 letras
# Algeria
# 7 letras

# %%
all = todos.merge(countries, how = 'inner', on='Country')
display(all)
# Out:
#           Country  CO2 Emission                               Region  \
# 0     Afghanistan     -0.898608        ASIA (EX. NEAR EAST)
# 1     Afghanistan     -0.941460        ASIA (EX. NEAR EAST)
# 2         Albania     -0.546310  EASTERN EUROPE
# 3         Albania     -0.682189  EASTERN EUROPE
# 4         Algeria      0.029516  NORTHERN AFRICA
# ..            ...           ...                                  ...
# 87  United States      1.527874  NORTHERN AMERICA
# 88        Uruguay     -0.726891              LATIN AMER. & CARIB
# 89      Venezuela      0.004432              LATIN AMER. & CARIB
# 90        Vietnam     -0.369276        ASIA (EX. NEAR EAST)
# 91       Zimbabwe      0.236882  SUB-SAHARAN AFRICA
#
#     Population  Area (sq. mi.) Pop. Density (per sq. mi.)  \
# 0     31056997          647500                       48,0
# 1     31056997          647500                       48,0
# 2      3581655           28748                      124,6
# ...

# %%
all['Country'].nunique()
# Out:
# 67

# %%
print(all.isnull().sum())
print(all.isna().sum())
print(all.shape)
# Out:
# Country                               0
# CO2 Emission                          0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Climate                               8
# Birthrate                             1
# Deathrate                             1
# Agriculture                           0
# Industry                              0
# dtype: int64
# Country                               0
# CO2 Emission                          0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# ...

# %%
all.dropna(inplace=True)
print(all.isnull().sum())
print("")
print("Shape:", all.shape)
print("Unique Countries:", all['Country'].nunique())
# Out:
# Country                               0
# CO2 Emission                          0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# dtype: int64
#
# Shape: (84, 16)
# Unique Countries: 61

# %%
display(all.Climate.unique())
print("\n")
print("Explicação do Significado de Climate:")
# Out:
# array(['1', '3', '2', '1,5', '2,5', '4'], dtype=object)
# Explicação do Significado de Climate:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
all.dtypes
# Out:
# Country                                object
# CO2 Emission                          float64
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)             object
# Coastline (coast/area ratio)           object
# Infant mortality (per 1000 births)     object
# GDP ($ per capita)                    float64
# Literacy (%)                           object
# Phones (per 1000)                      object
# Climate                                object
# Birthrate                              object
# Deathrate                              object
# Agriculture                            object
# Industry                               object
# dtype: object

# %%
print(all['Deathrate'][0:5])
all['Deathrate'] = all['Deathrate'].str.replace(',', '.').astype(float)
print(all['Deathrate'][0:5], end="\n\n")
all.dtypes
# Out:
# 0    20,34
# 1    20,34
# 2     5,22
# 3     5,22
# 4     4,61
# Name: Deathrate, dtype: object
# 0    20.34
# 1    20.34
# 2     5.22
# 3     5.22
# 4     4.61
# Name: Deathrate, dtype: float64
# Country                                object
# CO2 Emission                          float64
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)             object
# Coastline (coast/area ratio)           object
# Infant mortality (per 1000 births)     object
# GDP ($ per capita)                    float64
# Literacy (%)                           object
# Phones (per 1000)                      object
# Climate                                object
# Birthrate                              object
# Deathrate                             float64
# Agriculture                            object
# Industry                               object
# dtype: object

# %%
all['Pop. Density (per sq. mi.)'] = all['Pop. Density (per sq. mi.)'].str.replace(',', '.').astype(float)
all['Coastline (coast/area ratio)'] = all['Coastline (coast/area ratio)'].str.replace(',', '.').astype(float)
all['Infant mortality (per 1000 births)'] = all['Infant mortality (per 1000 births)'].str.replace(',', '.').astype(float)
all['Literacy (%)'] = all['Literacy (%)'].str.replace(',', '.').astype(float)
all['Phones (per 1000)'] = all['Phones (per 1000)'].str.replace(',', '.').astype(float)
all['Climate'] = all['Climate'].str.replace(',', '.').astype(float)
all['Birthrate'] = all['Birthrate'].str.replace(',', '.').astype(float)
all['Agriculture'] = all['Agriculture'].str.replace(',', '.').astype(float)
all['Industry'] = all['Industry'].str.replace(',', '.').astype(float)
all.dtypes
# Out:
# Country                                object
# CO2 Emission                          float64
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Infant mortality (per 1000 births)    float64
# GDP ($ per capita)                    float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# dtype: object

# %%
display(all.describe())
# Out:
#        CO2 Emission    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count     84.000000  8.400000e+01    8.400000e+01                   84.000000
# mean      -0.063238  8.244885e+07    1.321418e+06                  187.694048
# std        0.979595  2.318164e+08    2.385747e+06                  714.807534
# min       -0.998678  2.993880e+05    6.930000e+02                    2.600000
# 25%       -0.653580  8.221783e+06    1.088900e+05                   30.300000
# 50%       -0.305799  1.811103e+07    3.842075e+05                   66.300000
# 75%        0.055027  4.481843e+07    1.130073e+06                  124.875000
# max        4.835815  1.313974e+09    9.631420e+06                 6482.200000
#
#        Coastline (coast/area ratio)  Infant mortality (per 1000 births)  \
# count                     84.000000                           84.000000
# mean                       1.461310                           36.996310
# ...

# %%
all.query('Country == "Brazil"')
# Out:
#    Country  CO2 Emission                   Region  Population  Area (sq. mi.)  \
# 18  Brazil      0.005219  LATIN AMER. & CARIB       188078227         8511965
# 19  Brazil     -0.276296  LATIN AMER. & CARIB       188078227         8511965
#
#     Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 18                        22.1                          0.09
# 19                        22.1                          0.09
#
#     Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 18                               29.61              7600.0          86.4
# 19                               29.61              7600.0          86.4
#
#     Phones (per 1000)  Climate  Birthrate  Deathrate  Agriculture  Industry
# 18              225.3      2.0      16.56       6.17        0.084       0.4
# 19              225.3      2.0      16.56       6.17        0.084       0.4

# %% [markdown]
# # Visualização

# %%
# # Valores de emissão originais por país Europeus
# plt.subplot(2, 2, 1)
# plt.plot(copia, color='g', linewidth=2)
# plt.subplot(2, 2, 2)
# plt.hist(copia, color='g')

# # Valores de emissão originais por demais países
# plt.subplot(2, 2, 3)
# plt.plot(copia2)
# plt.subplot(2, 2, 4)
# plt.hist(copia2)

# plt.show()

# %%
# Valores de emissão padronizados por país Europeus
plt.subplot(2, 2, 1)
plt.plot(europe["CO2 Emission"], color='g', linewidth=2)
plt.plot([0,15,30],[0,0,0])
plt.subplot(2, 2, 2)
plt.hist(europe["CO2 Emission"], color='g')

# Valores de emissão padronizados por demais países
plt.subplot(2, 2, 3)
plt.plot(other['CO2 Emission'])
plt.plot([0,35,70],[0,0,0])
plt.subplot(2, 2, 4)
plt.hist(other['CO2 Emission'])
plt.show()

# %%
correlation = all.corr()
print(correlation)
# Out:
#                                     CO2 Emission  Population  Area (sq. mi.)  \
# CO2 Emission                            1.000000    0.048485        0.313974
# Population                              0.048485    1.000000        0.618449
# Area (sq. mi.)                          0.313974    0.618449        1.000000
# Pop. Density (per sq. mi.)              0.019000    0.000047       -0.098264
# Coastline (coast/area ratio)            0.119533   -0.095722       -0.186043
# Infant mortality (per 1000 births)     -0.345007   -0.008708       -0.146391
# GDP ($ per capita)                      0.570302   -0.053444        0.259751
# Literacy (%)                            0.302277   -0.020965        0.173802
# Phones (per 1000)                       0.439107    0.068258        0.372662
# Climate                                -0.237716   -0.029133       -0.079248
# Birthrate                              -0.358862   -0.143619       -0.281819
# ...

# %%
fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(all.corr(), annot=True, ax=ax)
plt.show()
# Out:
# <ipython-input-52-9159329d5b69>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(all.corr(), annot=True, ax=ax)

# %%
all.columns
# Out:
# Index(['Country', 'CO2 Emission', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Infant mortality (per 1000 births)', 'GDP ($ per capita)',
#        'Literacy (%)', 'Phones (per 1000)', 'Climate', 'Birthrate',
#        'Deathrate', 'Agriculture', 'Industry'],
#       dtype='object')

# %%
all2 = all.drop(['Population','Area (sq. mi.)','Pop. Density (per sq. mi.)','Coastline (coast/area ratio)','Infant mortality (per 1000 births)',
                 'Literacy (%)','Phones (per 1000)','Climate','Birthrate','Deathrate'], axis=1)
sns.pairplot(all2)

# %%
sns.relplot(x="Industry", y='CO2 Emission', hue='Region', data=all)

# %%
p = sns.jointplot(x="Industry", y='CO2 Emission', hue='Climate', data=all)
p.fig.suptitle("                             JointPlot - Emissão de CO2")
# Out:
# Text(0.5, 0.98, '                             JointPlot - Emissão de CO2')

# %%
sns.boxplot(x=all['CO2 Emission']).set(title='BoxPlot - Emissão de CO2')
# Out:
# [Text(0.5, 1.0, 'BoxPlot - Emissão de CO2')]

# %%
top10 = all.sort_values(by="CO2 Emission", ascending=False).head(10)
ax = top10['CO2 Emission'].sort_values().plot(kind="barh", title = "Top 10 Países com maior Emissão de CO2")
ax.set_xlabel("Emissão de CO2")
ax.set_ylabel("Países")
ax.set_yticklabels(top10["Country"][::-1])
plt.show()

# %%
top10 = all.sort_values(by="Industry", ascending=False).head(10)
ax = top10['Industry'].sort_values().plot(kind="barh", title = "Top 10 Maiores Países em Indústria")
ax.set_xlabel("Indústria")
ax.set_ylabel("Países")
ax.set_yticklabels(top10["Country"][::-1])
plt.show()

# %%
top = all.sort_values(by="CO2 Emission", ascending=False).reset_index(drop=True)
display(top.query("Country == 'Brazil'"))

print("\n")
top = all.sort_values(by="Industry", ascending=False).reset_index(drop=True)
top.query("Country == 'Brazil'")
# Out:
#    Country  CO2 Emission                   Region  Population  Area (sq. mi.)  \
# 22  Brazil      0.005219  LATIN AMER. & CARIB       188078227         8511965
# 39  Brazil     -0.276296  LATIN AMER. & CARIB       188078227         8511965
#
#     Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 22                        22.1                          0.09
# 39                        22.1                          0.09
#
#     Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 22                               29.61              7600.0          86.4
# 39                               29.61              7600.0          86.4
#
#     Phones (per 1000)  Climate  Birthrate  Deathrate  Agriculture  Industry
# 22              225.3      2.0      16.56       6.17        0.084       0.4
# 39              225.3      2.0      16.56       6.17        0.084       0.4
#    Country  CO2 Emission                   Region  Population  Area (sq. mi.)  \
# ...

# %%
top10 = all.sort_values(by="CO2 Emission", ascending=False)
top10 = top10[35:45]
ax = top10['CO2 Emission'].sort_values().plot(kind="barh", title = "Top 10 Países com maior Emissão de CO2")
ax.set_xlabel("Emissão de CO2")
ax.set_ylabel("Países")
ax.set_yticklabels(top10["Country"][::-1])
plt.show()

# %%
top10 = all.sort_values(by="Industry", ascending=False).head(19)
ax = top10['Industry'].sort_values().plot(kind="barh", title = "Top 10 Maiores Países em Indústria")
ax.set_xlabel("Indústria")
ax.set_ylabel("Países")
ax.set_yticklabels(top10["Country"][::-1])
plt.show()
